# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# define two sequences
f = np.random.randint(-99, 100, size=5)
g = np.random.randint(-99,100,size=3)

# %%
f,g
# Out:
# (array([ 73, -12,  73,  19, -15], dtype=int32),
#  array([-57,  46,  65], dtype=int32))

# %%
convolve = np.convolve(f,g)
print(convolve)
# Out:
# [-4161  4042    32  1495  6474   545  -975]

# %%
x = np.linspace(-3,3,20)
f = (255*np.exp(-0.5*x**2)).astype("int32")
g = np.array([-1,0,1])
fp = np.convolve(f,g[::-1],mode="same")

# %%
# 2D convolution with 2D kernel
from scipy.signal import convolve2d
from skimage import data, color

img = data.astronaut()
img = color.rgb2gray(img)

k = np.array([[1,0,0],[0,-8,0],[0,0,3]])
c = convolve2d(img,k,mode="same")

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

ax[0].imshow(img, cmap="gray")
ax[0].set_title("Original Grayscale")
ax[0].axis("off")

ax[1].imshow(c, cmap="gray")
ax[1].set_title("Convolved Image")
ax[1].axis("off")

plt.tight_layout()
plt.show()
